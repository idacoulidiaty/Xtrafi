# %%
pip install passlib
# Out:
# Requirement already satisfied: passlib in ./dataviz_xtrafi/lib/python3.12/site-packages (1.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall bcrypt -y
# Out:
# Found existing installation: bcrypt 4.3.0
# Uninstalling bcrypt-4.3.0:
#   Successfully uninstalled bcrypt-4.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bcrypt==4.0.1
# Out:
# Collecting bcrypt==4.0.1
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bcrypt
# Successfully installed bcrypt-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from passlib.hash import bcrypt
print(bcrypt.hash("admin"))
# Out:
# $2b$12$K00VvM58.C/xV/fJJmQejejfayLkdDPtSnQE076a4mF/mq8UXaVY6

# %%
print(bcrypt.hash("user"))
# Out:
# $2b$12$ALRhd9.csR1yfMMF.jfqSem3YmzzqHPhX4ma2bjFPI6YPoj1aJUCm

# %%
import streamlit as st
import streamlit_authenticator as stauth
st.write("📦 Version réelle utilisée :", getattr(stauth, "__version__", "inconnue"))
# Out:
# 2025-06-30 11:53:40.787 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-30 11:53:41.362
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/ida/Documents/Xtrafi/Data_viz/dataviz_xtrafi/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-06-30 11:53:41.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-30 11:53:41.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-30 11:53:41.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
