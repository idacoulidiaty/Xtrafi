# %%
import pandas as pd

# %%
f = pd.read_excel('data/restitution-41-20250418172522 jeux BI Ida.xls')
f
# Out:
#                                 Filtres sélectionnées  \
# 0                                     Type d'activité
# 1                                         Type entité
# 2                                Type partie prenante
# 3                             Périmètre consolidation
# 4                                            Contrôle
# 5                                  Exercice reporting
# 6                                 Période de collecte
# 7                                     Confidentialité
# 8                                             Secteur
# 9                                              Entité
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                 Entités concernées
# 15                                        US_Entité 1
# ...

# %%
df_onglet_2 = pd.read_excel('data/restitution-41-20250418172522 jeux BI Ida.xls', sheet_name="Restit Brute (Total Répdts)", engine="calamine")

# %%
df_onglet_2
# Out:
#     Unnamed: 0 Code NORME            Nom NORME  Source Code Axe\nRAPPORT  \
# 0          NaN       ESRS  ESRS directive CSRD  Xtrafi                 E
# 1          NaN        NaN                  NaN  Xtrafi               NaN
# 2          NaN        NaN                  NaN     NaN               NaN
# 3          NaN        NaN                  NaN     NaN               NaN
# 4          NaN        NaN                  NaN  Xtrafi               NaN
# ..         ...        ...                  ...     ...               ...
# 76         NaN        NaN                  NaN     NaN               NaN
# 77         NaN        NaN                  NaN     NaN               NaN
# 78         NaN        NaN                  NaN     NaN               NaN
# 79         NaN        NaN                  NaN     NaN               NaN
# 80         NaN        NaN                  NaN     NaN               NaN
#
#    Nom axe\nRAPPORT Code axe\nAPP   Nom axe\nAPP Code thématique\nRAPPORT  \
# ...

# %%
df_onglet_2.columns
# Out:
# Index(['Unnamed: 0', 'Code NORME', 'Nom NORME', 'Source', 'Code Axe\nRAPPORT',
#        'Nom axe\nRAPPORT', 'Code axe\nAPP', 'Nom axe\nAPP',
#        'Code thématique\nRAPPORT', 'Nom thématique\nRAPPORT',
#        'Code thématique\nAPP', 'Nom thématique\nAPP', 'Code Ind.N1\nRAPPORT',
#        'Nom Ind.N1\nRAPPORT', 'Code Ind.N1\nAPP', 'Nom Ind.N1\nAPP',
#        'Type de\ncompilation\nINDICATEUR\n(C = Cumul,\nM = Moyenne)',
#        'Type de\ndonnées\nINDICATEUR\n(Q = quantitatif,\nK = qualitatif,\nA = action)',
#        'Code Ind.N2\nRAPPORT', 'Nom Ind.N2\nRAPPORT', 'Code Ind.N2\nAPP',
#        'Nom Ind.N2\nAPP', 'Code Ind.N3\nRAPPORT', 'Nom Ind.N3\nRAPPORT',
#        'Code Ind.N3\nAPP', 'Nom Ind.N3\nAPP', 'Code question\nRAPPORT',
#        'Nom question\nRAPPORT', 'Code question\nAPP', 'Nom Question\nAPP',
#        '% pondération\nsecteur', 'Unité de\nsaisie', 'Unité\nconversion',
#        'Monnaie\nlocale', 'Unité\nValorisation\nfinancière',
# ...

# %%
# Out:
# The kernel failed to start as the Python Environment 'anaconda3 (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
